# %%
import pandas as pd
import numpy as np

data = pd.read_csv('chip_dataset.csv', sep= ',', encoding='utf-8', index_col=0)
data['Release Date'] = pd.to_datetime(data['Release Date'], errors='coerce', dayfirst=False)
releaseyear = data['Release Date'].dt.year.astype('Int64')
#data.dtypes
# Out:
# Product                          object
# Type                             object
# Release Date             datetime64[ns]
# Process Size (nm)               float64
# TDP (W)                         float64
# Die Size (mm^2)                 float64
# Transistors (million)           float64
# Freq (MHz)                      float64
# Foundry                          object
# Vendor                           object
# FP16 GFLOPS                     float64
# FP32 GFLOPS                     float64
# FP64 GFLOPS                     float64
# dtype: object

# %%
missing_count = data.isnull().sum()
print(missing_count)
data.loc[(data['Product'].duplicated())]
#data.loc[[4850,4851,4852]]
# Out:
# Product                     0
# Type                        0
# Release Date               75
# Process Size (nm)           9
# TDP (W)                   626
# Die Size (mm^2)           715
# Transistors (million)     711
# Freq (MHz)                  0
# Foundry                     0
# Vendor                      0
# FP16 GFLOPS              4318
# FP32 GFLOPS              2906
# FP64 GFLOPS              3548
# dtype: int64
#                        Product Type Release Date  Process Size (nm)  TDP (W)  \
# 24         AMD Athlon 64 3500+  CPU   2001-01-01               90.0     67.0
# 77         AMD Athlon 64 3500+  CPU   2005-05-31               90.0     67.0
# 110        AMD Athlon 64 3500+  CPU   2007-02-20               90.0     62.0
# 122        AMD Athlon 64 3000+  CPU   2005-04-14              130.0     62.0
# 146        Intel Pentium 4 506  CPU   2005-06-01               90.0     84.0
# ...                        ...  ...          ...                ...      ...
# ...

# %%
data.loc[(data['Product'] == 'NVIDIA GeForce GT 320M')]
# Out:
#                      Product Type Release Date  Process Size (nm)  TDP (W)  \
# 3745  NVIDIA GeForce GT 320M  GPU   2009-06-15               55.0     14.0
# 4851  NVIDIA GeForce GT 320M  GPU   2010-03-03               40.0     23.0
#
#       Die Size (mm^2)  Transistors (million)  Freq (MHz) Foundry  Vendor  \
# 3745            121.0                  314.0       500.0    TSMC  NVIDIA
# 4851            100.0                  486.0       500.0    TSMC  NVIDIA
#
#       FP16 GFLOPS  FP32 GFLOPS  FP64 GFLOPS
# 3745          NaN         80.0          NaN
# 4851          NaN         52.8          NaN

# %%
data.loc[(data['Process Size (nm)'].isnull())]
# Out:
#                                    Product Type Release Date  \
# 2254  NVIDIA GeForce GTX 470 PhysX Edition  GPU          NaT
# 2270                     3dfx Spectre 2000  GPU          NaT
# 2735  NVIDIA GeForce GTX 275 PhysX Edition  GPU   2010-02-16
# 3164                          ATI Fire GL2  GPU   2000-06-01
# 3518                          ATI Fire GL4  GPU   2001-03-14
# 3613                 NVIDIA GeForce GT 220  GPU   2009-10-12
# 3720                          ATI Fire GL3  GPU   2000-06-01
# 3743                NVIDIA GeForce GTX 295  GPU   2009-01-08
# 4050                     3dfx Spectre 3000  GPU          NaT
#
#       Process Size (nm)  TDP (W)  Die Size (mm^2)  Transistors (million)  \
# 2254                NaN    215.0            529.0                 3100.0
# 2270                NaN     30.0            131.0                   30.0
# 2735                NaN    219.0            470.0                 1400.0
# ...

# %%
subset_data1 = data[["Product","Type","Release Date", "Process Size (nm)", "TDP (W)", "Die Size (mm^2)","Transistors (million)","Freq (MHz)", "Vendor", "FP16 GFLOPS", "FP32 GFLOPS", "FP64 GFLOPS"]]
subset_data1.loc[(subset_data1['Product'].isnull() == False)]

cpu_subset = data[["Product","Type","Release Date", "Process Size (nm)", "TDP (W)", "Die Size (mm^2)","Transistors (million)","Freq (MHz)", "Vendor"]]
cpu_subset.loc[(cpu_subset['Product'].isnull() == False)]
#subset_data = data.loc[(data['Type'] == 'CPU') & (releaseyear <= 2017)]
#subset_data.head(2100)
# Out:
#                       Product Type Release Date  Process Size (nm)  TDP (W)  \
# 0         AMD Athlon 64 3500+  CPU   2007-02-20               65.0     45.0
# 1            AMD Athlon 200GE  CPU   2018-09-06               14.0     35.0
# 2        Intel Core i5-1145G7  CPU   2020-09-02               10.0     28.0
# 3       Intel Xeon E5-2603 v2  CPU   2013-09-01               22.0     80.0
# 4     AMD Phenom II X4 980 BE  CPU   2011-05-03               45.0    125.0
# ...                       ...  ...          ...                ...      ...
# 4849      NVIDIA Quadro 3000M  GPU   2011-02-22               40.0     75.0
# 4850            Intel GMA 950  GPU   2005-06-01               90.0      7.0
# 4851   NVIDIA GeForce GT 320M  GPU   2010-03-03               40.0     23.0
# 4852   NVIDIA GeForce FX 5200  GPU   2003-03-06              150.0      NaN
# 4853   NVIDIA GeForce 9300 SE  GPU   2008-06-01               65.0      NaN
#
# ...

# %%
# Out:
# Product                          object
# Type                             object
# Release Date             datetime64[ns]
# Process Size (nm)               float64
# TDP (W)                         float64
# Die Size (mm^2)                 float64
# Transistors (million)           float64
# Freq (MHz)                      float64
# Foundry                          object
# Vendor                           object
# FP16 GFLOPS                     float64
# FP32 GFLOPS                     float64
# FP64 GFLOPS                     float64
# dtype: object
